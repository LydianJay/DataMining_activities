# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix

dataset = pd.read_csv("//home//lydianjay//Documents//Data mining//dataset//penguins.csv")
dataset.replace('NA', np.nan, inplace = True)
dataset.replace(' ', np.nan, inplace = True)
dataset.dropna( inplace = True, how = 'any')
dataset = dataset[dataset.sex != '.']

sp = dataset[["bill_length_mm", "bill_depth_mm", "flipper_length_mm", "body_mass_g", "sex"]].loc[dataset["species"] == "Adelie"]

# %%
dataset.head()
# Out:
#    Unnamed: 0 species     island  bill_length_mm  bill_depth_mm  \
# 0           1  Adelie  Torgersen            39.1           18.7
# 1           2  Adelie  Torgersen            39.5           17.4
# 2           3  Adelie  Torgersen            40.3           18.0
# 4           5  Adelie  Torgersen            36.7           19.3
# 5           6  Adelie  Torgersen            39.3           20.6
#
#    flipper_length_mm  body_mass_g     sex  year
# 0              181.0       3750.0    male  2007
# 1              186.0       3800.0  female  2007
# 2              195.0       3250.0  female  2007
# 4              193.0       3450.0  female  2007
# 5              190.0       3650.0    male  2007

# %%
blength_mean = sp["bill_length_mm"].mean()
bmass_mean = sp["body_mass_g"].mean()

# %%
bill_length = []

body_mass = []

for d in sp["bill_length_mm"]:
    if d >= blength_mean:
        bill_length.append("Long Bill")
    else:
        bill_length.append("Short Bill")
sp["Bill_Length_Cat"] = bill_length
        

for d in sp["body_mass_g"]:
    if d >= bmass_mean:
        body_mass.append("High mass")
    else:
        body_mass.append("Low mass")

sp["Body_Mass_Cat"] = body_mass

# %%
sp.head()
# Out:
#    bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g     sex  \
# 0            39.1           18.7              181.0       3750.0    male
# 1            39.5           17.4              186.0       3800.0  female
# 2            40.3           18.0              195.0       3250.0  female
# 4            36.7           19.3              193.0       3450.0  female
# 5            39.3           20.6              190.0       3650.0    male
#
#   Bill_Length_Cat Body_Mass_Cat
# 0       Long Bill     High mass
# 1       Long Bill     High mass
# 2       Long Bill      Low mass
# 4      Short Bill      Low mass
# 5       Long Bill      Low mass

# %%
print("--------------------------------------------")
print("Predictor = Body Mass")
for bmass in sp["Body_Mass_Cat"].unique():
    for sex in sp["sex"].unique():
        c = sp["sex"].loc[  (sp["Body_Mass_Cat"] == bmass) & (sp["sex"] == sex)].count()
        print(sex, " with ", bmass, " count: ", c)
total = sp["sex"].count()
print("--------------------------------------------")
malehigh = sp["sex"].loc[  (sp["Body_Mass_Cat"] == "High mass") & (sp["sex"] == "male")].count()
malelow = sp["sex"].loc[  (sp["Body_Mass_Cat"] == "Low mass") & (sp["sex"] == "male")].count()
femalehigh = sp["sex"].loc[  (sp["Body_Mass_Cat"] == "High mass") & (sp["sex"] == "female")].count()
femalelow = sp["sex"].loc[  (sp["Body_Mass_Cat"] == "Low mass") & (sp["sex"] == "female")].count()
print("Accuracy for predicting males: %.2f" % (malehigh/total*100))
print("Error predictive value: %.2f" % (malelow/total*100))
print("Accuracy for predicting females: %.2f" % (femalelow/total*100))
print("Error predictive value: %.2f" % (femalehigh/total*100))
acc = (malehigh+femalelow)/total *100
print("Accuracy: %.2f" % (acc))
print("--------------------------------------------")
# Out:
# --------------------------------------------
# Predictor = Body Mass
# male  with  High mass  count:  61
# female  with  High mass  count:  8
# male  with  Low mass  count:  12
# female  with  Low mass  count:  65
# --------------------------------------------
# Accuracy for predicting males: 41.78
# Error predictive value: 8.22
# Accuracy for predicting females: 44.52
# Error predictive value: 5.48
# Accuracy: 86.30
# --------------------------------------------

# %%
print("--------------------------------------------")
print("Predictor = Bill length")
for blength in sp["Bill_Length_Cat"].unique():
    for sex in sp["sex"].unique():
        c = sp["sex"].loc[  (sp["Bill_Length_Cat"] == blength) & (sp["sex"] == sex)].count()
        print(sex, " with ", blength, " count: ", c)
        
print("--------------------------------------------")
malehigh = sp["sex"].loc[  (sp["Bill_Length_Cat"] == "Long Bill") & (sp["sex"] == "male")].count()
malelow = sp["sex"].loc[  (sp["Bill_Length_Cat"] == "Short Bill") & (sp["sex"] == "male")].count()
femalehigh = sp["sex"].loc[  (sp["Bill_Length_Cat"] == "Long Bill") & (sp["sex"] == "female")].count()
femalelow = sp["sex"].loc[  (sp["Bill_Length_Cat"] == "Short Bill") & (sp["sex"] == "female")].count()
print("Accuracy for predicting males: %.2f" % (malehigh/total*100))
print("Error predictive value: %.2f" % (malelow/total*100))
print("Accuracy for predicting females: %.2f" % (femalelow/total*100))
print("Error predictive value: %.2f" % (femalehigh/total*100))
acc = (malehigh+femalelow)/total *100
print("Accuracy: %.2f" % (acc))
print("--------------------------------------------")
# Out:
# --------------------------------------------
# Predictor = Bill length
# male  with  Long Bill  count:  55
# female  with  Long Bill  count:  18
# male  with  Short Bill  count:  18
# female  with  Short Bill  count:  55
# --------------------------------------------
# Accuracy for predicting males: 37.67
# Error predictive value: 12.33
# Accuracy for predicting females: 37.67
# Error predictive value: 12.33
# Accuracy: 75.34
# --------------------------------------------
